# %%
import ast
from pynwb import NWBHDF5IO, NWBFile, TimeSeries
import pandas as pd

# %%
import sys
sys.path.append('../')
from preprocessing.utils import *

# %%
# %matplotlib inline
import matplotlib.pyplot as pp

# %%
tf = '../example_data/sub_455219/sub-455219_ses-20190805T152117_trial_events.csv'

# %%
events = pd.read_csv( tf )
nTrials = len(events['id'])
D = return_times( events )

# %%
hit_or_miss = np.zeros(nTrials)
# hit = correct lick = 1; miss = incorrect lick = 0; ignore = no lick = -1
hit_or_miss[ events['outcome'].values=='hit']=1
hit_or_miss[ events['outcome'].values=='ignore']=-1  #animal didn't lick

# %%
accuracy = np.sum( hit_or_miss[hit_or_miss>-1])/len(hit_or_miss)
pp.imshow( hit_or_miss[:,np.newaxis], aspect='auto')
